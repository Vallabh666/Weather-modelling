# %% [markdown]
# <a href="https://colab.research.google.com/github/Vallabh666/Weather-modelling/blob/main/TASK_6_SE_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlip.pyplot as plt
def quadratic(x, a =- 1,b=0,c=10);
return a * x ** 2 + b * x + C

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the quadratic function
def quadratic(x):
    a, b, c = 1, -1, 0.5  # Example coefficients
    return a * x**2 + b * x + c

# Define stages and calculate positions
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]
x_positions = np.linspace(-2, 2, len(stages))
y_positions = quadratic(x_positions)
x_curve = np.linspace(-2.5, 2.5, 500)
y_curve = quadratic(x_curve)

plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle='-', label="Quadratic Curve")

for i in range(len(stages)):
    if i > 0:
        plt.plot([x_positions[i-1], x_positions[i]],
                 [y_positions[i-1], y_positions[i-1]], color="blue", linewidth=2)
        plt.plot([x_positions[i], x_positions[i]],
                 [y_positions[i-1], y_positions[i]], color="blue", linewidth=2)

    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5)
    plt.text(x_positions[i], y_positions[i] + 0.1, stages[i], ha='center', va='bottom', fontsize=10)

plt.xlabel("Stages")
plt.ylabel("Quadratic Value")
plt.title("Waterfall Model Stages Visualized on a Quadratic Curve")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the quadratic function
def quadratic(x):
    a, b, c = 1, -1, 0.5  # Example coefficients
    return a * x**2 + b * x + c

# Define stages and calculate positions
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]
x_positions = np.linspace(-2, 2, len(stages))
y_positions = quadratic(x_positions)
x_curve = np.linspace(-2.5, 2.5, 500)
y_curve = quadratic(x_curve)

# Plot the quadratic curve and stages
plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle='-', label="Quadratic Curve")

for i in range(len(stages)):
    if i > 0:
        plt.plot([x_positions[i-1], x_positions[i]],
                 [y_positions[i-1], y_positions[i-1]], color="blue", linewidth=2)
        plt.plot([x_positions[i], x_positions[i]],
                 [y_positions[i-1], y_positions[i]], color="blue", linewidth=2)

    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5)
    plt.text(x_positions[i], y_positions[i] + 0.1, stages[i], ha='center', va='bottom', fontsize=10)

# Style the plot
plt.title("Waterfall Model Representation Using Quadratic Curve", fontsize=14)
plt.xlabel("Stages", fontsize=12)
plt.ylabel("Value", fontsize=12)

# Add axis lines
plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
plt.axvline(0, color="black", linewidth=0.5, linestyle="--")

# Customize grid
plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the quadratic function
def quadratic(x):
    return x ** 2

# Define the stages of the Waterfall model
stages = ["Requirements", "Design", "Implementation", "Verification", "Maintenance"]

# Generate x positions for the stages
x_positions = np.linspace(-2, 2, len(stages))

# Calculate the corresponding y positions using the quadratic function
y_positions = quadratic(x_positions)

# Generate x values for the curve plot
x_curve = np.linspace(-2.5, 2.5, 500)
y_curve = quadratic(x_curve)

# Plot the quadratic curve
plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle='-', label="Quadratic Curve")

# Plot the stages
for i in range(len(stages)):
    if i > 0:
        plt.plot([x_positions[i-1], x_positions[i]],
                 [y_positions[i-1], y_positions[i-1]], color="blue", linewidth=2)
        plt.plot([x_positions[i], x_positions[i]],
                 [y_positions[i-1], y_positions[i]], color="blue", linewidth=2)

    # Mark each stage with a red dot and label
    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5)
    plt.text(x_positions[i], y_positions[i] + 0.1, stages[i], ha='center', va='bottom', fontsize=10)

# Style the plot
plt.title("Waterfall Model Representation Using Quadratic Curve", fontsize=14)
plt.xlabel("Stages", fontsize=12)
plt.ylabel("Value", fontsize=12)

# Add axis lines
plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
plt.axvline(0, color="black", linewidth=0.5, linestyle="--")

# Customize grid
plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)

# Add legend
plt.legend()

# Display the plot
plt.show()
